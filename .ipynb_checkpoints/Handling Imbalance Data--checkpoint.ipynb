# %% [markdown]
# ## Sampling

# %% [raw]
# - To bring balance in the data we have to oversample or undersample it so that the count of
# class labels in the target column are equal

# %% [raw]
# There are two types of sampling
# 1. Oversampling
# 2. Undersampling

# %% [markdown]
# ### Techniques

# %% [raw]
# 1. Random Oversampling
# 2. Random Undersampling
# 3. SMOTE (Synthetic Minority Oversampling Technique)

# %% [markdown]
# ### Random Oversamplin

# %% [raw]
# - It randomly add the duplicate samples from the existing samples of dataset

# %%
import pandas as pd
import numpy as np

# %%
pip install imblearb
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement imblearb (from versions: none)
# ERROR: No matching distribution found for imblearb

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
df = pd.read_csv("Diabetes.csv")

# %%
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df["Outcome"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Outcome'>

# %%
random_oversampling = RandomOverSampler()

# %%
x = df.drop("Outcome",axis = 1)

# %%
y = df["Outcome"]

# %%
x_oversampled, y_oversampled = random_oversampling.fit_resample(x,y)

# %%
y_oversampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
x_oversampled.sort_values(by = "Age")
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 55        73             50             10        0  23.0
# 413      143             74             22       61  26.2
# 819      177             60             29      478  34.6
# 60        84              0              0        0   0.0
# 414      138             60             35      167  34.6
# ..       ...            ...            ...      ...   ...
# 123      132             80              0        0  26.8
# 666      145             82             18        0  32.5
# 837      145             82             18        0  32.5
# 453      119              0              0        0  19.6
# 459      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age
# 55                      0.248   21
# 413                     0.256   21
# 819                     1.072   21
# 60                      0.304   21
# 414                     0.534   21
# ..                        ...  ...
# ...

# %% [markdown]
# ### Random Over Sampling with Sampling Strategy

# %%
random_oversampler = RandomOverSampler(sampling_strategy = 0.7)

# %%
x_resampled, y_resampled = random_oversampler.fit_resample(x,y)

# %%
y_resampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    350
# Name: count, dtype: int64

# %%
250/500
# Out:
# 0.5

# %%
# Means 50 % datat is missing

# %%
random_oversampler = RandomOverSampler(sampling_strategy=0.9)

# %%
x_resampled, y_resampled = random_oversampler.fit_resample(x,y)

# %%
y_resampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    450
# Name: count, dtype: int64

# %%
450/500
# Out:
# 0.9

# %%
# Means 10% data is missing

# %% [markdown]
# ### Random Undersamplin

# %% [raw]
# class1 >> 4500
# class2 >> 5000

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
random_undersampler = RandomUnderSampler()

# %%
y_oversampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %% [markdown]
# ### SMOTE (Synthetic Minority Over Sampling Technique)

# %%
from imblearn.over_sampling import SMOTE

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state = 10, k_neighbors=5)

x_oversampled, y_oversampled = smote.fit_resample(x,y)

# %%
y_oversampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
x_oversampled.sort_values("BloodPressure")
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 533       91              0              0        0  29.8
# 15       100              0              0        0  30.0
# 49       105              0              0        0   0.0
# 7        150              0              0        0  35.3
# 643       90              0              0        0  28.0
# ..       ...            ...            ...      ...   ...
# 549      189            110             31        0  28.5
# 177      129            110             46      130  67.1
# 43       171            110             24      240  45.4
# 691      158            114              0        0  42.3
# 106       96            122              0        0  22.4
#
#      DiabetesPedigreeFunction  Age
# 533                     0.501   31
# 15                      0.484   32
# 49                      0.305   24
# 7                       0.134   29
# 643                     0.610   31
# ..                        ...  ...
# ...

# %%
smote = SMOTE(k_neighbors=5)

x_oversampled, y_oversampled = smote.fit_resample(x,y)

y_oversampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64
